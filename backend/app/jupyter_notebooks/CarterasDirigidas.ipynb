# %%
import pandas as pd

# %%
pd.options.display.max_columns = 500
pd.options.display.max_rows = 10000

# %%
parse_dates = [
    'FECHA_SOLICITUD',
    'FECHA_APROBACION',
    'FECHA_LIQUIDACION',
    'FECHA_VENC_ORIGINAL',
    'FECHA_VENC_ACTUAL',
    'FECHA_REESTRUCTURACION',
    'FECHA_PRORROGA',
    'FECHA_ULTIMA_RENOVACION',
    'FECHA_CANCEL',
    'FECHA_VENC_ULTIMA_CUOTA_CAPITAL',
    'ULTIMA_FECHA_CANCEL_CUOTA_CAPITAL',
    'FECHA_VENC_ULTIMA_CUOTA_INTERES',
    'ULTIMA_FECHA_CANCEL_CUOTA_INTERES',
    'FECHA_ESTADO_FINANCIERO',
    'FECHA_EMISION_FACTIBILIDAD_TECNICA',
    'FECHA_AUTENTICACION',
    'FECHA_ULTIMA_INSPECCION',
    'FECHA_VENC_REGISTRO',
    'Upd_Date'
]

# %%
HLP = 6 # Hipotecario Largo Plazo
HCP = 7 # Hipotecario Corto Plazo
TURISMO = 8 # Turismo
MICROFINANCIERO = 9 # Microfinanciero
MANUFACTURA = 10 # Manufactura
AGRICOLA_ICG = 11 # Agricola ICG
AGRICOLA_OTHER_ICG = 12 # Agricola Other ICG

# %%
cd_agricola_gcg = pd.read_csv('../vol/web/media/insumos/automatic/RPT_STG_Dirigidas_AGRICOLA_CONSUMER.txt', sep='	', low_memory=False, parse_dates=parse_dates)
cd_agricola_icg = pd.read_csv('../vol/web/media/insumos/automatic/RPT_STG_Dirigidas_AGRICOLA_CORPORATE.txt', sep='	', low_memory=False, parse_dates=parse_dates)
cd_hlp = pd.read_csv('../vol/web/media/insumos/automatic/RPT_STG_Dirigidas_HIPOTECARIO_LARGO_PLAZO.txt', sep='	', low_memory=False, parse_dates=parse_dates)
cd_hcp = pd.read_csv('../vol/web/media/insumos/automatic/RPT_STG_Dirigidas_HIPOTECARIO_CORTO_PLAZO.txt', sep='	', low_memory=False, parse_dates=parse_dates)
cd_manufactura = pd.read_csv('../vol/web/media/insumos/automatic/RPT_STG_Dirigidas_MANUFACTURA.txt', sep='	', low_memory=False, parse_dates=parse_dates)
cd_micro = pd.read_csv('../vol/web/media/insumos/automatic/RPT_STG_Dirigidas_MICROFINANCIERO.txt', sep='	', low_memory=False, parse_dates=parse_dates)
cd_turismo = pd.read_csv('../vol/web/media/insumos/automatic/RPT_STG_Dirigidas_TURISMO.txt', sep='	', low_memory=False, parse_dates=parse_dates)

# %%
cd_agricola_gcg.head(1)
# Out:
#    COD_OFICINA  COD_CONTABLE  NUM_CREDITO  NUM_CREDITO_PRIMER_DESEMBOLSO  \
# 0            2    8190310400   9011605501                     9011605501
#
#    NUM_DESEMBOLSO  NATURALEZA_CLIENTE TIPO_CLIENTE  NUM_CLIENTE  \
# 0               1                   1            V     13801079
#
#                  NOMBRE_CLIENTE  GENERO  COOPERATIVA  CLIENTE_NUEVO  \
# 0  OLGA DANIELA DE ARMAS TEXIER       1            1              1
#
#    COD_PARROQUIA FECHA_SOLICITUD FECHA_APROBACION FECHA_LIQUIDACION  \
# 0         120601      2007-08-27       2007-08-27        2007-08-27
#
#    TIPO_CREDITO  PLAZO_CREDITO  CLASE_RIESGO  ESTADO_CREDITO  \
# 0             4              0             0               3
#
#    SITUACION_CREDITO  PERIODO_PAGO_CAPITAL  PERIODO_PAGO_INTERES  \
# 0                  0                     0                     0
#
#    PERIODO_GRACIA_CAPITAL FECHA_VENC_ORIGINAL FECHA_VENC_ACTUAL  \
# 0                       0          2010-08-27        2010-08-27
#
#   FECHA_REESTRUCTURACION  CANT_PRORROGAS FECHA_PRORROGA  CANT_RENOVACIONES  \
# 0             1900-01-01               0     1900-01-01                  0
#
#   FECHA_ULTIMA_RENOVACION FECHA_CANCEL FECHA_VENC_ULTIMA_CUOTA_CAPITAL  \
# 0              1900-01-01   1900-01-01                      2009-08-27
#
#   ULTIMA_FECHA_CANCEL_CUOTA_CAPITAL FECHA_VENC_ULTIMA_CUOTA_INTERES  \
# 0                        2009-12-01                      2009-08-27
#
#   ULTIMA_FECHA_CANCEL_CUOTA_INTERES  MONTO_ORIGINAL  MONTO_INICIAL  \
# 0                        2009-10-09         15000.0        15000.0
#
#    MONTO_LIQUIDADO_MES  SALDO  RENDIMIENTOS_X_COBRAR  \
# 0                  0.0   0.03                    0.0
#
#    RENDIMIENTOS_X_COBRAR_VENCIDOS  PROVISION_ESPECIFICA  \
# 0                             0.0                   0.0
#
#    PORCENTAJE_PROVISION_ESPECIFICA  PROVISION_RENDIMIENTO_X_COBRAR  \
# 0                              0.0                             0.0
#
#    TASA_INTERES_COBRADA  TASA_INTERES_ACTUAL  TASA_COMISION  \
# 0                  13.0                 13.0            0.0
#
#    EROGACIONES_RECUPERABLES  TIPO_GARANTIA_PRINCIPAL  NUM_CUOTAS  \
# 0                       0.0                        0           6
#
#    NUM_CUOTAS_VENCIDAS  MONTO_VENCIDO_30_DIAS  MONTO_VENCIDO_60_DIAS  \
# 0                    0                    0.0                    0.0
#
#    MONTO_VENCIDO_90_DIAS  MONTO_VENCIDO_120_DIAS  MONTO_VENCIDO_180_DIAS  \
# 0                    0.0                     0.0                     0.0
#
#    MONTO_VENCIDO_ANUAL  MONTO_VENCIDO_MAYOR_ANUAL  BANCA_SOCIAL  \
# 0                  0.0                        0.0             1
#
#    PRODUCCION_SOCIAL  MODALIDAD_MICROCREDITO  USO_FINANCIERO  \
# 0                  1                       0               0
#
#    DESTINO_RECURSOS_MICROFINANCIEROS  CANT_TRABAJADORES  VENTAS_ANUALES  \
# 0                                  0                  0               0
#
#   FECHA_ESTADO_FINANCIERO  NUM_RTN  LICENCIA_TURISTICA_NACIONAL  \
# 0              1900-01-01        0                            0
#
#   FECHA_EMISION_FACTIBILIDAD_TECNICA  \
# 0                         1900-01-01
#
#    NUM_EXPEDIENTE_FACTIBILIDAD_SOCIOTECNICA  \
# 0                                         0
#
#    NUM_EXPEDIENTE_CONFORMIDAD_TURISTICA  NOMBRE_PROYECTO  COD_TIPO_PROYECTO  \
# 0                                     0                0                  0
#
#    COD_TIPO_OPERACIONES_FINANCIAMIENTO  COD_SEGMENTO  TIPO_ZONA  \
# 0                                    0             0          0
#
#   FECHA_AUTENTICACION FECHA_ULTIMA_INSPECCION  PORCENTAJE_EJECUCION_PROYECTO  \
# 0          1900-01-01              1900-01-01                            0.0
#
#    PAGOS_EFECTUADOS_MENSUALES  MONTOS_LIQUIDADOS_CIERRE  \
# 0                           0                         0
#
#    AMORTIZACIONES_CAPITAL_ACUMULADAS  TASA_INCENTIVO  NUMERO_OFICIO_INCENTIVO  \
# 0                                  0               0                        0
#
#    NUM_REGISTRO  TIPO_REGISTRO FECHA_VENC_REGISTRO  TIPO_SUBSECTOR  RUBRO  \
# 0             0              0          1900-01-01               0      0
#
#    COD_USO  CANT  COD_UNIDAD_MEDIDA  SECTOR_PRODUCCION  CANT_HECTAREAS  \
# 0        0   0.0                  0                  0             0.0
#
#    SUPERFICIE_TOTAL  NUM_BENEFICIARIOS  PRIORITARIO  DESTINO_MANUFACTURERO  \
# 0               0.0                  0            0                      0
#
#    DESTINO_ECONOMICO  TIPO_BENEFICIARIO  MODALIDAD_HIPOTECARIA  \
# 0                  0                  0                      0
#
#    INGRESO_FAMILIAR  MONTO_LIQUIDADO_ANUAL  SALDO_CREDITO_31_12  \
# 0                 0                      0                    0
#
#    CANT_VIVIENDAS   Upd_Date
# 0               0 2019-12-05

# %%
cd_agricola_gcg.info(max_cols=200)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 107 columns):
# COD_OFICINA                                 11 non-null int64
# COD_CONTABLE                                11 non-null int64
# NUM_CREDITO                                 11 non-null int64
# NUM_CREDITO_PRIMER_DESEMBOLSO               11 non-null int64
# NUM_DESEMBOLSO                              11 non-null int64
# NATURALEZA_CLIENTE                          11 non-null int64
# TIPO_CLIENTE                                11 non-null object
# NUM_CLIENTE                                 11 non-null int64
# NOMBRE_CLIENTE                              11 non-null object
# GENERO                                      11 non-null int64
# COOPERATIVA                                 11 non-null int64
# CLIENTE_NUEVO                               11 non-null int64
# COD_PARROQUIA                               11 non-null int64
# FECHA_SOLICITUD                             11 non-null datetime64[ns]
# FECHA_APROBACION                            11 non-null datetime64[ns]
# FECHA_LIQUIDACION                           11 non-null datetime64[ns]
# TIPO_CREDITO                                11 non-null int64
# PLAZO_CREDITO                               11 non-null int64
# CLASE_RIESGO                                11 non-null int64
# ESTADO_CREDITO                              11 non-null int64
# SITUACION_CREDITO                           11 non-null int64
# PERIODO_PAGO_CAPITAL                        11 non-null int64
# PERIODO_PAGO_INTERES                        11 non-null int64
# PERIODO_GRACIA_CAPITAL                      11 non-null int64
# FECHA_VENC_ORIGINAL                         11 non-null datetime64[ns]
# FECHA_VENC_ACTUAL                           11 non-null datetime64[ns]
# FECHA_REESTRUCTURACION                      11 non-null datetime64[ns]
# CANT_PRORROGAS                              11 non-null int64
# FECHA_PRORROGA                              11 non-null datetime64[ns]
# CANT_RENOVACIONES                           11 non-null int64
# FECHA_ULTIMA_RENOVACION                     11 non-null datetime64[ns]
# FECHA_CANCEL                                11 non-null datetime64[ns]
# FECHA_VENC_ULTIMA_CUOTA_CAPITAL             11 non-null datetime64[ns]
# ULTIMA_FECHA_CANCEL_CUOTA_CAPITAL           11 non-null datetime64[ns]
# FECHA_VENC_ULTIMA_CUOTA_INTERES             11 non-null datetime64[ns]
# ULTIMA_FECHA_CANCEL_CUOTA_INTERES           11 non-null datetime64[ns]
# MONTO_ORIGINAL                              11 non-null float64
# MONTO_INICIAL                               11 non-null float64
# MONTO_LIQUIDADO_MES                         11 non-null float64
# SALDO                                       11 non-null float64
# RENDIMIENTOS_X_COBRAR                       11 non-null float64
# RENDIMIENTOS_X_COBRAR_VENCIDOS              11 non-null float64
# PROVISION_ESPECIFICA                        11 non-null float64
# PORCENTAJE_PROVISION_ESPECIFICA             11 non-null float64
# PROVISION_RENDIMIENTO_X_COBRAR              11 non-null float64
# TASA_INTERES_COBRADA                        11 non-null float64
# TASA_INTERES_ACTUAL                         11 non-null float64
# TASA_COMISION                               11 non-null float64
# EROGACIONES_RECUPERABLES                    11 non-null float64
# TIPO_GARANTIA_PRINCIPAL                     11 non-null int64
# NUM_CUOTAS                                  11 non-null int64
# NUM_CUOTAS_VENCIDAS                         11 non-null int64
# MONTO_VENCIDO_30_DIAS                       11 non-null float64
# MONTO_VENCIDO_60_DIAS                       11 non-null float64
# MONTO_VENCIDO_90_DIAS                       11 non-null float64
# MONTO_VENCIDO_120_DIAS                      11 non-null float64
# MONTO_VENCIDO_180_DIAS                      11 non-null float64
# MONTO_VENCIDO_ANUAL                         11 non-null float64
# MONTO_VENCIDO_MAYOR_ANUAL                   11 non-null float64
# BANCA_SOCIAL                                11 non-null int64
# PRODUCCION_SOCIAL                           11 non-null int64
# MODALIDAD_MICROCREDITO                      11 non-null int64
# USO_FINANCIERO                              11 non-null int64
# DESTINO_RECURSOS_MICROFINANCIEROS           11 non-null int64
# CANT_TRABAJADORES                           11 non-null int64
# VENTAS_ANUALES                              11 non-null int64
# FECHA_ESTADO_FINANCIERO                     11 non-null datetime64[ns]
# NUM_RTN                                     11 non-null int64
# LICENCIA_TURISTICA_NACIONAL                 11 non-null int64
# FECHA_EMISION_FACTIBILIDAD_TECNICA          11 non-null datetime64[ns]
# NUM_EXPEDIENTE_FACTIBILIDAD_SOCIOTECNICA    11 non-null int64
# NUM_EXPEDIENTE_CONFORMIDAD_TURISTICA        11 non-null int64
# NOMBRE_PROYECTO                             11 non-null int64
# COD_TIPO_PROYECTO                           11 non-null int64
# COD_TIPO_OPERACIONES_FINANCIAMIENTO         11 non-null int64
# COD_SEGMENTO                                11 non-null int64
# TIPO_ZONA                                   11 non-null int64
# FECHA_AUTENTICACION                         11 non-null datetime64[ns]
# FECHA_ULTIMA_INSPECCION                     11 non-null datetime64[ns]
# PORCENTAJE_EJECUCION_PROYECTO               11 non-null float64
# PAGOS_EFECTUADOS_MENSUALES                  11 non-null int64
# MONTOS_LIQUIDADOS_CIERRE                    11 non-null int64
# AMORTIZACIONES_CAPITAL_ACUMULADAS           11 non-null int64
# TASA_INCENTIVO                              11 non-null int64
# NUMERO_OFICIO_INCENTIVO                     11 non-null int64
# NUM_REGISTRO                                11 non-null int64
# TIPO_REGISTRO                               11 non-null int64
# FECHA_VENC_REGISTRO                         11 non-null datetime64[ns]
# TIPO_SUBSECTOR                              11 non-null int64
# RUBRO                                       11 non-null int64
# COD_USO                                     11 non-null int64
# CANT                                        11 non-null float64
# COD_UNIDAD_MEDIDA                           11 non-null int64
# SECTOR_PRODUCCION                           11 non-null int64
# CANT_HECTAREAS                              11 non-null float64
# SUPERFICIE_TOTAL                            11 non-null float64
# NUM_BENEFICIARIOS                           11 non-null int64
# PRIORITARIO                                 11 non-null int64
# DESTINO_MANUFACTURERO                       11 non-null int64
# DESTINO_ECONOMICO                           11 non-null int64
# TIPO_BENEFICIARIO                           11 non-null int64
# MODALIDAD_HIPOTECARIA                       11 non-null int64
# INGRESO_FAMILIAR                            11 non-null int64
# MONTO_LIQUIDADO_ANUAL                       11 non-null int64
# SALDO_CREDITO_31_12                         11 non-null int64
# CANT_VIVIENDAS                              11 non-null int64
# Upd_Date                                    11 non-null datetime64[ns]
# dtypes: datetime64[ns](19), float64(24), int64(62), object(2)
# memory usage: 9.3+ KB
