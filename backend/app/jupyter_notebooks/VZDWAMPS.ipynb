# %%
import pandas as pd

# %%
pd.options.display.max_columns = 500
pd.options.display.max_rows = 10000

# %%
labels = [
    'ORG', 
    'ACCT', 
    'CUSTORG', 
    'CUSTNBR', 
    'RELORG', 
    'RELNBR', 
    'PRICARD', 
    'LOGO', 
    'SOURCECODE', 
    'DATEXFREFF', 
    'DATEBLOCK1', 
    'BLOCKCODE1', 
    'BLOCKREASON1', 
    'BLOCKCODE2', 
    'BLOCKREASON2', 
    'DATEBLOCK2', 
    'DATECLOSE', 
    'DATELASTMAINT', 
    'STATEOFISSUE', 
    'INTSTATUS', 
    'DATELASTSTATEX', 
    'XFRORG', 
    'XFRLOGO', 
    'XFRACCT', 
    'DATECARDEXP', 
    'DATEOPENED', 
    'BILLINGCYCLE', 
    'DATELASTSTM', 
    'CURRBAL', 
    'HIBAL', 
    'DATEHIBAL', 
    'CRLIM', 
    'CASHBAL', 
    'DATECRBAL', 
    'LASTCRLIM', 
    'DATELINEDEC', 
    'DATELINEINC', 
    'HISTORY', 
    'FILLER', 
    'PMTCURRDUE', 
    'PMTPASTCTR', 
    'PMTPASTDUE', 
    'PMT30CTR', 
    'PMT30', 
    'PMT60CTR', 
    'PMT60', 
    'PMT90CTR', 
    'PMT90', 
    'PMT120CTR', 
    'PMT120', 
    'PMT150CTR', 
    'PMT150', 
    'PMT180CTR', 
    'PMT180', 
    'PMT210CTR', 
    'PMT210', 
    'CHGOFFSTATUS', 
    'DATECGOFF', 
    'AMTCGOFF', 
    'CHGOFFRSN1', 
    'CHGOFFRSN2', 
    'RISKLEVEL', 
    'NBRUNBLKCARD', 
    'NBRNSF', 
    'LASTYTDINT', 
    'LASTYTDINTPAID', 
    'CURRYTDINDPAID', 
    'DATELASTPURCH', 
    'DATELASTRETURN', 
    'DATELASTACT', 
    'CARDUSAGE', 
    'FITESTDIGITS', 
    'FIAMTATRISKFACTOR', 
    'FIAMTATRISK', 
    'FISPID', 
    'FIREPRSCENID', 
    'FIREPRSTRAGID', 
    'FICOMMSCENID', 
    'FICOMMSTRAGID', 
    'FIDELQSCENID', 
    'FIDELQSTRAGID', 
    'FIAUTHSCENID', 
    'FIAUTHSTRAGID', 
    'FICRLIMSCENID', 
    'FICRLIMSTRAGID', 
    'FIOVLMSCENID', 
    'FIOVLMSTRAGID', 
    'FICURRBEHAVIORSCORE', 
    'FICRLIMITCTRLIND', 
    'OVERLIMNBROFCYCLES', 
    'TYPEOFACCT', 
    'DATECARDFEE', 
    'WAIVFEE', 
    'DDAACCTNBR', 
    'EMPLOYEECODE', 
    'CYCANRBAL', 
    'CYCANRDAYS', 
    'MTHANRBAL', 
    'MTHANRDAYS', 
    'DATEPMTDUE', 
    'DATELASTPMT', 
    'PMTLASTAMT', 
    'FILLER2', 
    'CHANNELID', 
    'SOURCEID', 
    'CAMPAIGNID', 
    'TESTID', 
    'SEGMENTID', 
    'DAYSPASTDUE', 
    'NUMPMTSPASTDUE', 
    'BUCKETREAL',
    ]

fwidths = []
